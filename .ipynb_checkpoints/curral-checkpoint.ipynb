# %%
import pandas as pd

# %%
df = pd.read_csv("./mensagens_jairmbolsonaro1_channel_metadata.csv", )
df
# Out:
#         id                                               text        data  \
# 0       13  - Acordo com o Japão para o desenvolvimento de...  2021-01-11
# 1       14  Rio Grande do Sul: Governo Jair Messias Bolson...  2021-01-11
# 2       15                                                NaN  2021-01-11
# 3       17                                                NaN  2021-01-11
# 4       18                       https://youtu.be/qlNKtgXbdb4  2021-01-11
# ...    ...                                                ...         ...
# 2426  2533  Imagens de passagens de fauna diretamente de n...  2021-10-11
# 2427  2534  Aproximadamente 405 kg de cloridrato de cocaín...  2021-10-11
# 2428  2535  Em sua primeira ação, o programa Rios+Limpos r...  2021-10-11
# 2429  2536  Curso Alfabetização Baseada na Ciência (ABC): ...  2021-10-11
# 2430  2537  A digitalização de serviços públicos avança no...  2021-10-11
#
#           hora   views  encaminhamentos
# ...

# %% [markdown]
# Importante: o index do dataframe é diferente do id das mensagens(que é sequencial) porque algumas mensagens parecem ter sido apagadas e suas informações não podem ser recuperadas - apesar do id continuar sua sequência independente disso, é claro
